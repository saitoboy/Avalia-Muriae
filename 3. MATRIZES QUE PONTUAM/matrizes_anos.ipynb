# %% [markdown]
# # 1 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('1anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 2 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('2anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 3 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('3anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 4 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('4anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 5 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('5anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 1 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('1anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 2 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('2anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 3 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('3anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 4 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('4anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 5 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('5anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 6 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 26))  # Aumentado para 26
    percent = point * 0.04  # Ajustando a pontuação percentual para a nova quantidade de questões

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('6anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 7 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 26))  # Aumentado para 26
    percent = point * 0.04  # Ajustando a pontuação percentual para a nova quantidade de questões

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('7anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 8 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 26))  # Aumentado para 26
    percent = point * 0.04  # Ajustando a pontuação percentual para a nova quantidade de questões

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('8anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 9 ANO MAT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 26))  # Aumentado para 26
    percent = point * 0.04  # Ajustando a pontuação percentual para a nova quantidade de questões

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('9anomat_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 6 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('6anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 7 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('7anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 8 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('8anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)

# %% [markdown]
# # 9 ANO PORT #

# %%
import pandas as pd

def read_reference_matrix(file_path):
    # Lê o arquivo Excel
    df = pd.read_excel(file_path)

    # Cria um dicionário vazio para armazenar a matriz de referência
    reference_matrix = {}

    # Itera sobre cada linha do DataFrame
    for index, row in df.iterrows():
        # Cria um dicionário para armazenar os dados da linha
        row_data = {
            'gabarito': row['Gabarito'],
            'hexadecimal': row['Hexadecimal'],
            'orientacao_pedagogica': row['Orientação'],
            'pontuacao': row['Soma']
        }

        # Adiciona o dicionário ao dicionário da matriz de referência
        reference_matrix[row['Questão']] = row_data

    return reference_matrix

def anomat_1ano(df, reference_matrix):
    for column, data in reference_matrix.items():
        df.insert(loc=df.columns.get_loc(f"QUESTÃO {column}")+1, column=f"G{column}", value=data['gabarito'])
        df.insert(loc=df.columns.get_loc(f"G{column}")+1, column=f"H{column}", value=data['hexadecimal'])
        df.insert(loc=df.columns.get_loc(f"H{column}")+1, column=f"O{column}", value=data['orientacao_pedagogica'])
        df.insert(loc=df.columns.get_loc(f"O{column}")+1, column=f"S{column}", value=(df[f"QUESTÃO {column}"]==data['gabarito']).astype(int))

    point = sum(df[f"S{i}"].apply(pd.to_numeric, errors='coerce') for i in range(1, 21))
    percent = point * 0.05

    df.insert(loc=len(df.columns), column='PONTUAÇÃO', value=point)
    df.insert(loc=len(df.columns), column='PERCENTUAL', value=percent)

    return df

# Lê a matriz de referência
reference_matrix = read_reference_matrix('9anoport_matriz.xlsx')

# Lê o arquivo Excel com as respostas dos alunos
df = pd.read_excel('respostas_alunos.xlsx')

# Atualiza o DataFrame com a matriz de referência
df = anomat_1ano(df, reference_matrix)

# Salva o DataFrame modificado de volta para o arquivo Excel
df.to_excel('respostas_alunos_modificado.xlsx', index=False)
